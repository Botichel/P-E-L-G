# %% [markdown]
# Exercise 1

# %% [markdown]
# These are some examples of a text in programming language.

# %%
print("Hi Everyone")
# Out:
# Hi Everyone

# %%
print("Excellent day")
# Out:
# Excellent day

# %%
print("Hello, it's me again")
# Out:
# Hello, it's me again

# %% [markdown]
# For this it is important to put the "print" function, which is what would capture what is written inside, but also without forgetting the use of quotes at the end of the text you want to print on the screen.
#
# In some programs you usually need to "print" by adding the letter "f" thus giving "printf", the difference is not much since in some programs it is usually written a little differently but with the same structure.

# %% [markdown]
# ![shutterstock_1375463840.width-800.jpg](attachment:shutterstock_1375463840.width-800.jpg)

# %% [markdown]
# Do not worry if in your editor you do not get the same, as it was said before, in each program it is something different as much as the color or something else.
#
# In your editor you can see a numbering on the left side of "1" onwards, which indicate the lines listed where the person writes, which also helps identify any errors that may be found that affect the running of the program, in case that there is an error.
